# %% [markdown]
# <a href="https://colab.research.google.com/github/AriadniTzanaki/datastories_for_emme/blob/main/%CE%91%CF%83%CE%BA%CE%B7%CF%83%CE%B5%CE%B9%CF%82%20week10/Askhseis_lesson10%20new.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Ασκήσεις για Μάθημα 10**

# %%
# !python -m spacy download el_core_news_sm
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.6/12.6 MB 24.2 MB/s eta 0:00:00
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('el_core_news_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import spacy
from wordcloud import WordCloud, STOPWORDS

# %%
nlp = spacy.load('el_core_news_sm')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
skai_df = pd.read_csv("/content/drive/MyDrive/skai.gr-MAY23.csv")

# %%
skai_df
# Out:
#          site                                                url        date  \
# 0     skai.gr  https://www.skai.gr/news/world/to-vatikano-sym...  2023-05-01
# 1     skai.gr  https://www.skai.gr/news/world/meksiko-18-tour...  2023-05-01
# 2     skai.gr  https://www.skai.gr/news/greece/eortologio-poi...  2023-05-01
# 3     skai.gr  https://www.skai.gr/news/world/soudan-i-vretan...  2023-05-01
# 4     skai.gr  https://www.skai.gr/news/greece/fotia-ta-ksime...  2023-05-01
# ...       ...                                                ...         ...
# 5161  skai.gr  https://www.skai.gr/news/politics/androulakis-...  2023-05-31
# 5162  skai.gr  https://www.skai.gr/news/sports/apotheosi-vero...  2023-05-31
# 5163  skai.gr  https://www.skai.gr/news/world/san-simera-i-la...  2023-05-31
# 5164  skai.gr  https://www.skai.gr/news/world/germania-epithy...  2023-05-31
# 5165  skai.gr  https://www.skai.gr/news/politics/paylos-marin...  2023-05-31
#
# ...

# %%
skai_df.dropna(inplace=True)

# %%
skai_df=skai_df.reset_index(drop=True)

# %%
skai_df
# Out:
#          site                                                url        date  \
# 0     skai.gr  https://www.skai.gr/news/world/to-vatikano-sym...  2023-05-01
# 1     skai.gr  https://www.skai.gr/news/world/meksiko-18-tour...  2023-05-01
# 2     skai.gr  https://www.skai.gr/news/greece/eortologio-poi...  2023-05-01
# 3     skai.gr  https://www.skai.gr/news/world/soudan-i-vretan...  2023-05-01
# 4     skai.gr  https://www.skai.gr/news/greece/fotia-ta-ksime...  2023-05-01
# ...       ...                                                ...         ...
# 4978  skai.gr  https://www.skai.gr/news/politics/androulakis-...  2023-05-31
# 4979  skai.gr  https://www.skai.gr/news/sports/apotheosi-vero...  2023-05-31
# 4980  skai.gr  https://www.skai.gr/news/world/san-simera-i-la...  2023-05-31
# 4981  skai.gr  https://www.skai.gr/news/world/germania-epithy...  2023-05-31
# 4982  skai.gr  https://www.skai.gr/news/politics/paylos-marin...  2023-05-31
#
# ...

# %%
skai_df.describe()
# Out:
#            site                                                url  \
# count      4983                                               4983
# unique        1                                               4983
# top     skai.gr  https://www.skai.gr/news/world/to-vatikano-sym...
# freq       4983                                                  1
#
#               date section                      title   author  \
# count         4983    4983                       4983     4983
# unique          31      19                       4966      197
# top     2023-05-31  Κόσμος  Ποια γιορτή είναι σήμερα   skai.gr
# freq           353    1548                         10     2379
#
#                                                      text
# count                                                4983
# unique                                               4983
# top     Το Βατικανό εμπλέκεται σε μια ειρηνευτική αποσ...
# freq                                                    1

# %%
skai_df.columns
# Out:
# Index(['site', 'url', 'date', 'section', 'title', 'author', 'text'], dtype='object')

# %%
skai_df['datetime']=pd.to_datetime(skai_df['date'],format='%Y-%m-%d')

# %%
skai_df['year']=pd.DatetimeIndex(skai_df['datetime']).year
skai_df['month']=pd.DatetimeIndex(skai_df['datetime']).month
skai_df['day']=pd.DatetimeIndex(skai_df['datetime']).day

# %%
skai_df["full_text"]=skai_df["title"]+" "+skai_df["text"]

# %%
skai_df['text'] =skai_df[['title', 'full_text']].agg(' '.join, axis=1)

# %%
 skai_df[['date', "section"]].describe()
# Out:
#               date section
# count         4983    4983
# unique          31      19
# top     2023-05-31  Κόσμος
# freq           353    1548

# %%
skai_df['datetime'] = pd.to_datetime(skai_df['date'], format='%Y-%m-%d')
skai_df['day'] = pd.DatetimeIndex(skai_df['datetime']).day

# %%
skai_df[skai_df["section"]=="Κόσμος"].groupby("day", as_index=False)['title'].count().sort_values("title", ascending=False)
# Out:
#     day  title
# 30   31     97
# 11   12     97
# 4     5     88
# 22   23     80
# 3     4     72
# 9    10     71
# 20   21     69
# 14   15     59
# 25   26     58
# 24   25     58
# 15   16     58
# 7     8     57
# 23   24     56
# 29   30     52
# 17   18     50
# 1     2     47
# 18   19     47
# 19   20     45
# 8     9     42
# 16   17     41
# 27   28     38
# 6     7     38
# 2     3     36
# 5     6     34
# 26   27     31
# 12   13     30
# 0     1     24
# 13   14     24
# 28   29     20
# 10   11     16
# 21   22     13

# %%
skai_df[(skai_df["section"]=="Κόσμος") & (skai_df["day"]==6)]["text"]
# Out:
# 734    Live εικόνα από το Λονδίνο - Η ώρα της στέψης ...
# 739    H ιστορική τελετή στέψης του Κάρολου – Υπερθέα...
# 745    Σουδάν: Οι εμπόλεμες πλευρές θα συναντηθούν σή...
# 746    Μπάιντεν: Απών από τη στέψη, αλλά θα συναντήσε...
# 766    Υεμένη: Δύο στρατιώτες σκοτώθηκαν σε βομβιστικ...
# 774    Ελβετία: Ο Ζελένσκι θα μιλήσει στο ελβετικό κο...
# 789    Στέψη Καρόλου: Τα χαρακτηριστικά της τελετής σ...
# 791    DW: Πώς ο Ερντογάν στοχοποιεί τη ΛΟΑΤΚΙ+ κοινό...
# 832    Μεσανατολικό: Δύο Παλαιστίνιοι σκοτώθηκαν σε ι...
# 861    Παραγουάη: Συνελήφθη ο υποψήφιος για την προεδ...
# 868    Παραδόσεις που χάνονται στα βάθη των αιώνων στ...
# 873    Νεπάλ: Ένας νεκρός και τέσσερις τραυματίες από...
# 879    Διαδηλωτές ζητούν δικαιοσύνη για τον άστεγο Αφ...
# 889    Σουδάν-ΟΗΕ: Περισσότεροι από δύο εκατομμύρια ά...
# 895    Ο Κάρολος Γ’ στέφθηκε βασιλιάς της Βρετανίας σ...
# 899    Ουκρανία: Έξι Ουκρανοί ναρκοσυλλέκτες νεκροί α...
# ...

# %%
skai_df['date'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='date'>

# %%
skai_df['section'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='section'>

# %%
 wordcloud = WordCloud(
     stopwords = nlp.Defaults.stop_words,
     width = 2000,
     height = 1000,
     background_color = 'brown'
  ).generate(' '.join(skai_df[(skai_df["section"]=="Κόσμος") & (skai_df["day"]==6)]["text"]))
 fig = plt.figure(
     figsize = (10, 8),
     facecolor = 'k',
     edgecolor = 'k')
 plt.imshow(wordcloud, interpolation = 'bilinear')
 plt.axis('off')
 plt.tight_layout(pad=0)
 plt.show()

# %%
 wordcloud = WordCloud(
     stopwords = nlp.Defaults.stop_words,
     width = 2000,
     height = 1000,
     background_color = 'pink'
  ).generate(' '.join(token.lemma_ for token in nlp(' '.join(skai_df[(skai_df["section"]=="Κόσμος") & (skai_df["day"]==6)]["text"]))))
 fig = plt.figure(
     figsize = (10, 8),
     facecolor = 'k',
     edgecolor = 'k')
 plt.imshow(wordcloud, interpolation = 'bilinear')
 plt.axis('off')
 plt.tight_layout(pad=0)
 plt.show()

# %% [markdown]
# ΣΥΜΠΕΡΑΣΜΑΤΑ
# Λαμβάνοντας υπόψη τα παραπάνω ευρήματα, φαίνεται πως η μέρα με την μεγαλύτερη ειδησεογραφία ήταν στις 31.05.23 στο skai.gr ενώ οι περισσότεροι τίτλοι ήταν κοινωνικού περιεχομένου και άνηκαν στην κατηγορία "Κόσμος". Πιο συγκεκριμένα με την ανάλυση των wordclouds φαίνεται πως το θέμα των περισσοτέρων άρθρων είχαν να κάνουν με τη στέψη του Πρίγκιπα Καρόλου στη Μεγάλη Βρετανία, καθώς βρίσκουμε λέξεις όπως: Βασιλιάς Κάρολος, στέψη, Μπάκιγχαμ, Βρετανία,βασιλικός.
